# %%
import numpy as np, matplotlib.pyplot as plt

# %%
def fun(x):
    return 2*x*x -x + 4

def par(a,b,c,x):
    return a*x*x + b*x + c
size = 1001
ran = 100
x = np.linspace(-ran,ran,size)
y  = fun(x)
np.random.seed(3) # random seed = 29

# a,b,c = np.random.random(3)
a,b,c = np.random.random_integers(-50,50,3)

y2 = par(a,b,c,x)
plt.plot(x,y2)
plt.plot(x,y)
# Out:
# C:\Users\91762\AppData\Local\Temp\ipykernel_1616\34244232.py:13: DeprecationWarning: This function is deprecated. Please call randint(-50, 50 + 1) instead
#   a,b,c = np.random.random_integers(-50,50,3)

# %%
a,b,c
# Out:
# (-26, -47, 6)

# %%
def loss(a,b,c,fun,x):
    return abs(par(a,b,c,x) - fun(x))

def totloss(x):
    return (np.mean([loss(a,b,c,fun,xx) for xx in x]))

err = totloss(x)
err
# Out:
# 93518.24119880122

# %%
# Curve fitting: change a,b,c to minimize error
# Gradient descent: change a,b,c to minimize error

# Gradient descent

def dlossa(a,b,c,fun,x):
    s = [(par(a,b,c,xx) - fun(xx))*xx*xx for xx in x ]
    return 2*np.mean(s)

def dlossb(a,b,c,fun,x):
    s = [(par(a,b,c,xx) - fun(xx))*xx*100 for xx in x ]
    return 2*np.mean(s)

def dlossc(a,b,c,fun,x):
    s = [(par(a,b,c,xx) - fun(xx))*20 for xx in x ]
    return 2*np.mean(s)

da,db,dc = dlossa(a,b,c,fun,x),dlossb(a,b,c,fun,x),dlossc(a,b,c,fun,x)
da,db,dc
# Out:
# (-1124469623.68, -30728000.000000365, -3740720.0000000005)

# %%
import math
num_epochs = 3000

# lr = (10**-(math.log10(max(da,db,dc))+2*math.log(max(da,db,dc),100)))
lr = 3e-9
print(f'lr = {lr}')
import time
for epoch in range(num_epochs):
    a -= lr*dlossa(a,b,c,fun,x)
    b -= lr*dlossb(a,b,c,fun,x)
    c -= lr*dlossc(a,b,c,fun,x)
    err = totloss(x)
    if epoch%(num_epochs//10) == 0 :
        print(f"Epoch {epoch+1}/{num_epochs}, Loss = {err}")
        # plot the graph, pause for 0.1 sec
        y2 = par(a,b,c,x)
        y = fun(x)
        plt.clf() # clear the previous plot
        # plt.plot(x,y2,)
        # thickness
        plt.plot(x,y2,linewidth=5)
        plt.plot(x,y)
        plt.show()
        time.sleep(0.1)
        

print(f"Final Loss = {err}")
print(f"a = {a}, b = {b}, c = {c}")
# Out:
# lr = 3e-09
# Epoch 1/3000, Loss = 82251.10924769382
# Epoch 301/3000, Loss = 1258.7259498140584
# Epoch 601/3000, Loss = 689.5598481461107
# Epoch 901/3000, Loss = 377.758763743177
# Epoch 1201/3000, Loss = 206.94857969131036
# Epoch 1501/3000, Loss = 113.37785615757157
# Epoch 1801/3000, Loss = 62.12318954739053
# Epoch 2101/3000, Loss = 34.05475747537268
# Epoch 2401/3000, Loss = 18.696469839063994
# Epoch 2701/3000, Loss = 10.315522308325166
# Final Loss = 5.791283873100539
# a = 1.9996537600803095, b = -1.1119849616457051, c = 6.081590705796851

# %%
print(a,b,c)
print(da,db,dc)
print('diff', a-2,b+1,c-4)
print('%diff', (a-2)/2 * 100, (b+1)/1 * 100, (c-4)/4 * 100)
plt.plot(x,par(a,b,c,x),linewidth=5)
plt.plot(x,y)
# Out:
# 1.9996537600803095 -1.1119849616457051 6.081590705796851
# -1124469623.68 -30728000.000000365 -3740720.0000000005
# diff -0.0003462399196905164 -0.11198496164570515 2.0815907057968506
# %diff -0.01731199598452582 -11.198496164570514 52.03976764492126

# %% [markdown]
# Assignment :
# Now do for another equation of Hignher Degree.
# Do try for np.sin(x) also :)
